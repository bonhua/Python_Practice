# %% [markdown]
# # <center> 09 Python Visualization with Matplotlib

# %% [markdown]
# __[Pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)__
#
# __[Matplotlib documentation](https://matplotlib.org/stable/plot_types/index.html)__

# %% [markdown]
# ## Module Notes

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
xpoints = [1,3,6,7]
ypoints = [3,6,14,21]

# %%
# plot(x,y)

plt.plot(xpoints, ypoints)

# %%
# scatter(x,y)

plt.scatter(xpoints, ypoints)

# %%
# bar(x,height)/barh(y,width)

plt.bar(xpoints, ypoints)

# %%
# stem(x,y)

plt.stem(xpoints, ypoints)

# %%
# step(x,y)

plt.step(xpoints, ypoints)

# %%
# fill_between(x, y1, y2)

ypoints2 = [10,18,27,35]
plt.fill_between(xpoints, ypoints, ypoints2)

# %% [markdown]
# ***

# %% [raw]
# plt.figure()
#
# df.plot(x="xaxis", y="yaxis")
#
# df.plot.bar(x="xaxis", y=["yaxis","yaxis2"])
# df.plot.scatter(x="xaxis", y="yaxis")
# df.plot.hist(y=["yaxis"], bins=25)
#
# df.plot.scatter(x="xaxis", y="yaxis", marker="o", s=100, c="Black", fontsize=20, rot=45)
# plt.show()
#
# df.plot(x="xaxis", y="yaxis", color="green")
#
# df.plot.bar(x="xaxis", y="yaxis", color=["blue","red","red","blue","blue","blue","blue"])
#
# df.plot.line(x="xaxis", subplots=True) # single chart w/ multiple plots!
# plt.show()

# %% [markdown]
# Python Markers (marker = " "):
#     o - circle
#     * - star
#     . = point
#     , = pixel
#     x = X
#     X = X(filled)
#     + = plus
#     P = plus(filled)
#     s = square
#     D = diamond
#     d = diamond(thin)
#     p = pentagon
#     H = hexagon
#     h = hexagon
#     v = triangle down
#     ^ = triangle up
#     < = triangle left
#     > = triangle right
#     1 = triangle down
#     2 = triangle up
#     3 = triangle left
#     4 = triangle right
#     | = Vline
#     _ = Hline

# %% [markdown]
# ***

# %% [markdown]
# ## Class Challenge Time!

# %% [markdown]
# Generate three visualizations of your choice and share an insight.

# %%
countries = pd.read_csv("countries_clean.csv")

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          227 non-null    int64
#  1   Country                             227 non-null    object
#  2   Region                              227 non-null    object
#  3   Population                          227 non-null    int64
#  4   Area (sq. mi.)                      227 non-null    int64
#  5   Pop. Density (per sq. mi.)          227 non-null    float64
#  6   Coastline (coast/area ratio)        227 non-null    float64
#  7   Net migration                       227 non-null    float64
#  8   Infant mortality (per 1000 births)  227 non-null    float64
#  9   GDP ($ per capita)                  227 non-null    float64
#  10  Literacy (%)                        227 non-null    float64
# ...

# %%
countries.describe()
# Out:
#        Unnamed: 0    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  227.000000  2.270000e+02    2.270000e+02                  227.000000
# mean   113.000000  2.874028e+07    5.982270e+05                  379.047137
# std     65.673435  1.178913e+08    1.790282e+06                 1660.185825
# min      0.000000  7.026000e+03    2.000000e+00                    0.000000
# 25%     56.500000  4.376240e+05    4.647500e+03                   29.150000
# 50%    113.000000  4.786994e+06    8.660000e+04                   78.800000
# 75%    169.500000  1.749777e+07    4.418110e+05                  190.150000
# max    226.000000  1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     227.000000
# mean                      21.165330       0.037621
# std                       72.286863       4.856712
# min                        0.000000     -20.990000
# ...

# %%
countries.head(10)

# %%
countries.columns

# %%
countries_lean = countries.drop(columns = ["Unnamed: 0", "Area (sq. mi.)", "Country", "Coastline (coast/area ratio)", "Infant mortality (per 1000 births)", "Phones (per 1000)", "Birthrate", "Deathrate"])
countries_lean

# %%
# let's look at literacy and GDP

# define your axes
# x = GDP
# y = literacy

# select size of chart
plt.figure(figsize=(10,4))

# select and plot your chart
plt.scatter(countries["GDP ($ per capita)"], countries["Literacy (%)"], marker='.', color='#3B7AAE')

# customize your labels
plt.xlabel("GDP ($ per capita)")
plt.ylabel("Literacy (%)")
plt.title("Literacy (%) vs. GDP ($ per capita)")

# %%
# let's look at literacy and GDP

# define your axes
# y = GDP
# x = literacy

# select size of chart
plt.figure(figsize=(10,4))

# select and plot your chart
plt.scatter(countries["Literacy (%)"], countries["GDP ($ per capita)"], marker='.', color='#3B7AAE')

# customize your labels
plt.ylabel("GDP ($ per capita)")
plt.xlabel("Literacy (%)")
plt.title("Literacy (%) vs. GDP ($ per capita)")

# %%
countries_lean

# %%
countries_lean.Region.unique()

# %%
literacy_us = countries.pivot_table(index="Country", values="Literacy (%)",

# %%
df = df.pivot_table(index=" ", values=" ", columns=" ")
df

# %%
brooklyn_pizza= pizza_df[pizza_df['borough']=='Brooklyn']

cheap_pizza = pizza_df[ pizza_df["Price as number"] < 4]
cheap_pizza.head(10)

# %%
baltics_countries = countries[ countries["Region"] == "Baltics                            "]
baltics_countries
# Out:
#      Unnamed: 0     Country                               Region  Population  \
# 64           64    Estonia   Baltics                                 1324333
# 114         114     Latvia   Baltics                                 2274735
# 120         120  Lithuania   Baltics                                 3585906
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 64            45226                        29.3                          8.39
# 114           64589                        35.2                          0.82
# 120           65200                        55.0                          0.14
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 64           -3.16                                7.87             12300.0
# 114          -2.23                                9.55             10200.0
# 120          -0.71                                6.89             11400.0
#
# ...

# %%
countries.Region.unique()
# Out:
# array(['Asia (Ex. Near East)         ',
#        'Eastern Europe                     ',
#        'Northern Africa                    ',
#        'Oceania                            ',
#        'Western Europe                     ',
#        'Sub-Saharan Africa                 ', 'Latin Amer. & Carib    ',
#        'C.W. Of Ind. States ', 'Near East                          ',
#        'Northern America                   ',
#        'Baltics                            '], dtype=object)

# %%
above_avg_litrate = countries[ countries["Literacy (%)"] > 76.269604]
above_avg_litrate
# Out:
#      Unnamed: 0             Country                               Region  \
# 1             1            Albania   Eastern Europe
# 3             3     American Samoa   Oceania
# 4             4            Andorra   Western Europe
# 6             6           Anguilla               Latin Amer. & Carib
# 7             7  Antigua & Barbuda               Latin Amer. & Carib
# ..          ...                 ...                                  ...
# 216         216         Uzbekistan                  C.W. Of Ind. States
# 218         218          Venezuela               Latin Amer. & Carib
# 219         219            Vietnam         Asia (Ex. Near East)
# 225         225             Zambia   Sub-Saharan Africa
# 226         226           Zimbabwe   Sub-Saharan Africa
#
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 1       3581655           28748                       124.6
# 3         57794             199                       290.4
# ...

# %%
above_avg_litrate_asc = above_avg_litrate.sort_values(by="Literacy (%)", ascending = True)
above_avg_litrate_asc = above_avg_litrate_asc.reset_index(drop = True)
above_avg_litrate_asc.head(25)
# Out:
#     Unnamed: 0                Country                               Region  \
# 0           37            Cape Verde   Sub-Saharan Africa
# 1          197                 Syria   Near East
# 2          212  United Arab Emirates   Near East
# 3          200              Tanzania   Sub-Saharan Africa
# 4          179          Saudi Arabia   Near East
# 5           35              Cameroon   Sub-Saharan Africa
# 6          178   Sao Tome & Principe   Sub-Saharan Africa
# 7           96                  Iran         Asia (Ex. Near East)
# 8           26              Botswana   Sub-Saharan Africa
# 9           61           El Salvador               Latin Amer. & Carib
# 10         225                Zambia   Sub-Saharan Africa
# 11         194             Swaziland   Sub-Saharan Africa
# 12         166                 Qatar   Near East
# 13         118                 Libya   Northern Africa
# 14          70         French Guiana               Latin Amer. & Carib
# ...

# %%
above_avg_litrate_desc = above_avg_litrate.sort_values(by="Literacy (%)", ascending = False)
above_avg_litrate_desc = above_avg_litrate_desc.reset_index(drop = True)
above_avg_litrate_desc.head(25)
# Out:
#     Unnamed: 0          Country                               Region  \
# 0            4         Andorra   Western Europe
# 1          154          Norway   Western Europe
# 2           54         Denmark   Western Europe
# 3           11       Australia   Oceania
# 4           68         Finland   Western Europe
# 5          121      Luxembourg   Western Europe
# 6          119   Liechtenstein   Western Europe
# 7           53  Czech Republic   Eastern Europe
# 8           93         Iceland   Western Europe
# 9          163          Poland   Eastern Europe
# 10          64         Estonia   Baltics
# 11         114          Latvia   Baltics
# 12         211         Ukraine                  C.W. Of Ind. States
# 13         186        Slovenia   Eastern Europe
# 14         176           Samoa   Oceania
# 15         169          Russia                  C.W. Of Ind. States
# 16         120       Lithuania   Baltics
# 17          18         Belarus                  C.W. Of Ind. States
# ...

# %%
above_avg_litrate_desc.head(7)
# Out:
#    Unnamed: 0         Country                               Region  \
# 0           4        Andorra   Western Europe
# 1         154         Norway   Western Europe
# 2          54        Denmark   Western Europe
# 3          11      Australia   Oceania
# 4          68        Finland   Western Europe
# 5         121     Luxembourg   Western Europe
# 6         119  Liechtenstein   Western Europe
#
#    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0       71201             468                       152.1
# 1     4610820          323802                        14.2
# 2     5450661           43094                       126.5
# 3    20264082         7686850                         2.6
# 4     5231372          338145                        15.5
# 5      474413            2586                       183.5
# 6       33987             160                       212.4
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                          0.00           6.60
# ...

# %%
above_avg_litrate

Region

Literacy (%) - avg

What is the average literacy rate by region for above_avg_litrate?

# %%
# What is the average literacy rate by region?
# x-axis is region
# y-axis is avg Literacy rate

# avg lit rate by region
avg_litrate = countries.pivot_table(index="Region", values="Literacy (%)")
avg_litrate = avg_litrate.sort_values(by="Literacy (%)", ascending = False)
avg_litrate
# Out:
#                                      Literacy (%)
# Region
# Baltics                                 99.733333
# C.W. Of Ind. States                     98.725000
# Latin Amer. & Carib                     88.640000
# Western Europe                          80.821429
# Asia (Ex. Near East)                    79.553571
# Northern America                        78.200000
# Eastern Europe                          72.816667
# Oceania                                 71.914286
# Near East                               69.581250
# Sub-Saharan Africa                      61.284314
# Northern Africa                         56.033333

# %%
Region = ["Baltics", "C.W. Of Ind. States", "Latin Amer. & Carib", "Western Europe", "Asia (Ex. Near East)", "Northern America", "Eastern Europe", "Oceania", "Near East", "Sub-Saharan Africa", "Northern Africa"]
Literacy = [99.733333, 98.725000, 88.640000, 80.821429, 79.553571, 78.200000, 72.816667, 71.914286, 69.581250, 61.284314, 56.033333]
# Avg Literacy (%) = 76.269604
# Green = above avg; red = below avg

plt.figure(figsize=(25,5))

plt.bar(Region, Literacy, color=["#307D5A","#307D5A","#307D5A","#307D5A","#307D5A","#307D5A","#7D3330","#7D3330","#7D3330","#7D3330","#7D3330"], edgecolor="black")

plt.xlabel("Region")
plt.ylabel("Average Literacy (%)")
plt.title("Average Literacy (%) by Region")
# Out:
# Text(0.5, 1.0, 'Average Literacy (%) by Region')

# %%
plt.figure(figsize=(10,4))

plt.bar(avg_litrate["Region"], avg_litrate["Literacy (%)"], color="#3B60AE", edgecolor="black")

plt.xlabel("Region")
plt.ylabel("Average Literacy (%)")
plt.title("Average Literacy (%) by Region")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# configure size of plot: figsize(width, height)
plt.figure(figsize=(10,4))

# type of plot, x-axis, y-axis
plt.bar(df_sorted_grades_desc['Name'], df_sorted_grades_desc['Grade'], color="#FFB76B", edgecolor="black")

# customize labels
plt.xlabel('Name')
plt.ylabel('Grade')
plt.title('Grades by Name')
